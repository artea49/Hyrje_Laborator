# %% [markdown]
# # LAB06 - Matja e Madhesive: Gjatesia, Masa dhe Koha
# ---
# - ##### Tema: **Matja e madhesive: Gjatesia, Masa dhe Koha**
# - ##### Studentja: Artea Zerellari
# - ##### Pedagogu: Ervin Kafexhiu
# - ##### Data: 19.04.2026
# ---

# %% [markdown]
# ## Permbledhje :
#
# Qellimi i ketij eksperimenti ishte matja e madhesive baze fizike si gjatesia duke perdorur instrumente të ndryshme si vizore, kaliper vernier dhe sferometer. U kryen disa matje për secilin objekt per të vleresuar pasigurite dhe precizionin e instrumenteve.
#
# Rezultatet treguan se instrumentet me rezolucion me te larte, si kaliperi dhe sferometri, japin matje me te sakta dhe me te qendrueshme. U analizuan gjithashtu gabimet sistematike dhe rastesore qe ndikojne ne rezultatet perfundimtare.
#
# Ne perfundim, eksperimenti thekson rendesine e analizes se pasigurise dhe perdorimit te instrumenteve te pershtatshme per matje te sakta.

# %% [markdown]
# ---
# ## Hyrje :
#
# Matja eshte nje proces themelor ne fizike dhe perfaqeson krahasimin e nje madhesie fizike me nje njesi standarde. Çdo matje shoqerohet me nje pasiguri, e cila duhet te merret parasysh ne analize.
#
# Ne kete laborator u perdoren instrumente te ndryshme per matjen e gjatesise, duke perfshire vizoren, kaliperin vernier dhe sferometrin. Qellimi eshte te krahasohet precizioni i tyre dhe te identifikohen burimet e gabimeve.
#
# Pasiguria e matjes shprehet si:

# %% [markdown]
# $$
# x = x_{\text{mat}} \pm \Delta x
# $$

# %% [markdown]
# ---
# ## Aparatura dhe Materialet :
#
# Ne kete eksperiment u perdoren:
#
# - Vizore (rezolucion i ulet)
# - Kaliper vernier (precizion me i larte)
# - Sferometer (per matje shume te vogla si trashesia e xhamit)
# - Objekte: bateri, suste dhe xham

# %% [markdown]
# ---
# ## Procedura Eksperimentale :
#
# Per secilin objekt u kryen disa matje te perseritura duke perdorur instrumente te ndryshme. Per baterine dhe susten u perdoren vizorja dhe kaliperi, ndersa per xhamin u perdoren kaliperi dhe sferometri.
#
# U kryen te pakten 5 matje per secilin rast dhe te dhenat u regjistruan per analize te metejshme.

# %% [markdown]
# ---
# ## Mbledhja e te Dhenave :
#
# Te dhenat jane marre nga matje te perseritura per secilin objekt dhe jane ruajtur ne file ne folderin data/.
#
# Ne vijim paraqiten te dhenat e paperpunuara per secilin objekt.

# %% [markdown]
# ## Data e Ngarkimit :

# %%
import numpy as np

battery = np.loadtxt("data/battery.dat")
spring = np.loadtxt("data/spring.dat")
glass = np.loadtxt("data/glass.dat")

# %% [markdown]
# ---
# ## Bateria :
#
# | Madhesia(cm) | Matja 1 | Matja 2 | Matja 3 | Matja 4 | Matja 5 | Mesatarja | Pasiguria |
# |--------------|---------|---------|---------|---------|---------|-----------|-----------|
# | Vizore | 4.4 | 4.5 | 4.4 | 4.5 | 4.4 | 4.44 | 0.05 | ±0.05 |
# | Kaliper | 4.46 | 4.47 | 4.45 | 4.46 | 4.47 | 4.46 | ±0.01 |

# %% [markdown]
# ---
# ## Susta :
#
# | Madhesia(cm) | Matja 1 | Matja 2 | Matja 3 | Matja 4 | Matja 5 | Mesatarja | Pasiguria |
# |--------------|---------|---------|---------|---------|---------|-----------|-----------|
# | Vizore | 5.0 | 5.1 | 5.0 | 5.0 | 5.1 | 5.04 | ± 0.05 |
# | Kaliper | 4.80 | 4.82 | 4.81 | 4.80 | 4.82 | 4.81 | ±0.01 |
#
# ---

# %% [markdown]
# ## Xhami
#
# | Madhesia(cm) | Matja 1 | Matja 2 | Matja 3 | Matja 4 | Matja 5 | Mesatarja | Pasiguria |
# |--------------|---------|---------|---------|---------|---------|-----------|-----------|
# | Vizore | 5.0 | 5.1 | 5.0 | 5.0 | 5.1 | 5.04 | ± 0.01 |
# | Sferometer | 0.118 | 0.119 | 0.117 | 0.118 | 0.119 | 0.118 | ±0.005 |
#
# ---

# %% [markdown]
# ## Shfaqja e te dhenave:

# %%
print("Battery:", battery)
print("Spring:", spring)
print("Glass:", glass)
# Out:
# Battery: [4.46 4.47 4.45 4.46 4.47]
# Spring: [4.8  4.82 4.81 4.8  4.81]
# Glass: [0.118 0.119 0.117 0.118 0.119]

# %% [markdown]
# ---
# ## Analiza e te Dhenave :
#
# Per secilin set te dhenash llogaritet mesatarja dhe devijimi standard per te vleresuar shperndarjen e matjeve dhe pasigurine statistikore.

# %% [markdown]
# $$
# \bar{x} = \frac{1}{N} \sum x_i
# $$
#
#
#
# ---

# %% [markdown]
# ## Llogaritjet :

# %%
print("Battery mean:", np.mean(battery))
print("Battery std:", np.std(battery))

print("Spring mean:", np.mean(spring))
print("Spring std:", np.std(spring))

print("Glass mean:", np.mean(glass))
print("Glass std:", np.std(glass))
# Out:
# Battery mean: 4.462
# Battery std: 0.007483314773547723
# Spring mean: 4.808
# Spring std: 0.007483314773548008
# Glass mean: 0.1182
# Glass std: 0.0007483314773547845

# %% [markdown]
# ---
# ## Tabela e Permbledhjes :
#
# | Objekti | Mesatarja (cm) | Devijimi |
# |--------|---------------|----------|
# | Bateria | 4.46 | 0.01 |
# | Susta | 4.81 | 0.01 |
# | Xhami | 0.118 | 0.005 |

# %% [markdown]
# ---
# ## Diskutim :
#
# Rezultatet tregojne se matjet e kryera me kaliper dhe sferometer jane me te qendrueshme dhe kane shperndarje me te vogel krahasuar me vizoren.
#
# Kjo tregon se instrumentet me rezolucion me te larte ofrojne precizion me te madh. Diferencat e vogla midis matjeve sugjerojne pranine e gabimeve rastesore, ndersa ndryshimet midis instrumenteve mund të tregojne gabime sistematike.
#
# Burimi kryesor i pasigurise eshte rezolucioni i instrumenteve dhe faktori njerezor gjate matjes.

# %% [markdown]
# ---
# ## Perfundime :
#
# Ne kete laborator u arrit matja e madhesive baze dhe u analizuan pasigurite e tyre. U vertetua se instrumentet me te avancuara si kaliperi dhe sferometri japin rezultate me te sakta.
#
# Rezultatet perfundimtare jane:
#
# - Bateria: (4.46 ± 0.01) cm
# - Susta: (4.81 ± 0.01) cm
# - Xhami: (0.118 ± 0.005) cm
#
# Keto rezultate jane ne perputhje me pritshmerite teorike dhe tregojne rendesine e analizes se pasigurise ne matje.
#
# ---
